# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv(r"C:\Users\sharvani dhulipala\OneDrive\Documents\data mining lab\data.data")
data.head()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204 entries, 0 to 203
# Data columns (total 26 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   3            204 non-null    int64
#  1   ?            204 non-null    object
#  2   alfa-romero  204 non-null    object
#  3   gas          204 non-null    object
#  4   std          204 non-null    object
#  5   two          204 non-null    object
#  6   convertible  204 non-null    object
#  7   rwd          204 non-null    object
#  8   front        204 non-null    object
#  9   88.60        204 non-null    float64
#  10  168.80       204 non-null    float64
#  11  64.10        204 non-null    float64
#  12  48.80        204 non-null    float64
#  13  2548         204 non-null    int64
#  14  dohc         204 non-null    object
#  15  four         204 non-null    object
#  16  130          204 non-null    int64
#  17  mpfi         204 non-null    object
# ...

# %% [markdown]
# ## data.info()

# %%
data.replace("?",np.nan,inplace=True)
data.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration no-of-doors  \
# 0          3               NaN  alfa-romero       gas        std         two
# 1          3               NaN  alfa-romero       gas        std         two
# 2          1               NaN  alfa-romero       gas        std         two
# 3          2               164         audi       gas        std        four
# 4          2               164         audi       gas        std        four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
avg_norm_loss=data['normalized-losses'].astype('float').mean(axis=0)
print(avg_norm_loss)
data['normalized-losses'].replace(np.nan,avg_norm_loss,inplace=True)
data.head()
# Out:
# 122.0
#    symboling normalized-losses         make fuel-type aspiration no-of-doors  \
# 0          3             122.0  alfa-romero       gas        std         two
# 1          3             122.0  alfa-romero       gas        std         two
# 2          1             122.0  alfa-romero       gas        std         two
# 3          2               164         audi       gas        std        four
# 4          2               164         audi       gas        std        four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
avg_wheel_base=data['wheel-base'].mean(axis=0)
print(avg_wheel_base)
# Out:
# 98.75658536585367

# %%
data['wheel-base'].replace(np.nan,avg_wheel_base,inplace=True)
data.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration no-of-doors  \
# 0          3             122.0  alfa-romero       gas        std         two
# 1          3             122.0  alfa-romero       gas        std         two
# 2          1             122.0  alfa-romero       gas        std         two
# 3          2               164         audi       gas        std        four
# 4          2               164         audi       gas        std        four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
avg_len=data["length"].mean(axis=0)
data["length"].replace(np.nan,avg_len,inplace=True)
print(avg_len)
# Out:
# 174.04926829268288

# %%
avg_width=data["width"].mean(axis=0)
data["width"].replace(np.nan,avg_width,inplace=True)
print(avg_width)
# Out:
# 65.90780487804878

# %%
avg_height=data["height"].mean(axis=0)
data["height"].replace(np.nan,avg_height,inplace=True)
print(avg_height)
# Out:
# 53.72487804878049

# %%
avg_engine_size=data["engine-size"].mean(axis=0)
data["engine-size"].replace(np.nan,avg_engine_size,inplace=True)
print(avg_engine_size)
# Out:
# 126.90731707317073

# %%
avg_curb_weight=data["curb-weight"].mean(axis=0)
data["curb-weight"].replace(np.nan,avg_curb_weight,inplace=True)
print(avg_curb_weight)
# Out:
# 2555.5658536585365

# %%
avg_city_mpg=data["city-mpg"].mean(axis=0)
data["city-mpg"].replace(np.nan,avg_city_mpg,inplace=True)
print(avg_city_mpg)
# Out:
# 25.21951219512195

# %%
avg_highway_mpg=data["highway-mpg"].mean(axis=0)
data["highway-mpg"].replace(np.nan,avg_highway_mpg,inplace=True)
print(avg_highway_mpg)
# Out:
# 30.75121951219512

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   no-of-doors        203 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num_of-cylinder    205 non-null    object
# ...

# %%
data['make']=data['make'].astype('category')
data['make']=data['make'].cat.codes
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    int8
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   no-of-doors        203 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num_of-cylinder    205 non-null    object
# ...

# %%
data['fuel-type'].unique()
data['fuel-type']=data['fuel-type'].astype('category')
data['fuel-type']=data['fuel-type'].cat.codes
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    int8
#  3   fuel-type          205 non-null    int8
#  4   aspiration         205 non-null    object
#  5   no-of-doors        203 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num_of-cylinder    205 non-null    object
# ...

# %%
print(data['aspiration'].unique())
data['aspiration']=data['aspiration'].astype('category')
data['aspiration']=data['aspiration'].cat.codes
data.info()
# Out:
# ['std' 'turbo']
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    int8
#  3   fuel-type          205 non-null    int8
#  4   aspiration         205 non-null    int8
#  5   no-of-doors        203 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
# ...

# %%
print(data['no-of-doors'].unique())
data.tail()
data['no-of-doors']=data['no-of-doors'].astype('category')
data['no-of-doors']=data['no-of-doors'].cat.codes
data.info()
data.tail()
# Out:
# ['two' 'four' nan]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    int8
#  3   fuel-type          205 non-null    int8
#  4   aspiration         205 non-null    int8
#  5   no-of-doors        205 non-null    int8
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
# ...

# %%
print(data['body-style'].unique())
data['body-style']=data['body-style'].astype('category')
data['body-style']=data['body-style'].cat.codes
data.info()
data.head()
# Out:
# ['convertible' 'hatchback' 'sedan' 'wagon' 'hardtop']
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    int8
#  3   fuel-type          205 non-null    int8
#  4   aspiration         205 non-null    int8
#  5   no-of-doors        205 non-null    int8
#  6   body-style         205 non-null    int8
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
# ...

# %%
print(data['drive-wheels'].unique())
data['drive-wheels']=data['drive-wheels'].astype('category')
data['drive-wheels']=data['drive-wheels'].cat.codes
data.info()
data.head()
# Out:
# ['rwd' 'fwd' '4wd']
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    int8
#  3   fuel-type          205 non-null    int8
#  4   aspiration         205 non-null    int8
#  5   no-of-doors        205 non-null    int8
#  6   body-style         205 non-null    int8
#  7   drive-wheels       205 non-null    int8
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
# ...

# %%
print(data['engine-location'].unique())
data['engine-location']=data['engine-location'].astype('category')
data['engine-location']=data['engine-location'].cat.codes
data.info()
data.head()
# Out:
# ['front' 'rear']
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    int8
#  3   fuel-type          205 non-null    int8
#  4   aspiration         205 non-null    int8
#  5   no-of-doors        205 non-null    int8
#  6   body-style         205 non-null    int8
#  7   drive-wheels       205 non-null    int8
#  8   engine-location    205 non-null    int8
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num_of-cylinder    205 non-null    object
# ...

# %%
print(data['engine-type'].unique())
data['engine-type']=data['engine-type'].astype('category')
data['engine-type']=data['engine-type'].cat.codes
data.info()
data.head()
# Out:
# ['dohc' 'ohcv' 'ohc' 'l' 'rotor' 'ohcf' 'dohcv']
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    int8
#  3   fuel-type          205 non-null    int8
#  4   aspiration         205 non-null    int8
#  5   no-of-doors        205 non-null    int8
#  6   body-style         205 non-null    int8
#  7   drive-wheels       205 non-null    int8
#  8   engine-location    205 non-null    int8
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    int8
# ...

# %%
print(data['num_of-cylinder'].unique())
data['num_of-cylinder']=data['num_of-cylinder'].astype('category')
data['num_of-cylinder']=data['num_of-cylinder'].cat.codes
data.info()
data.head()
# Out:
# ['four' 'six' 'five' 'three' 'twelve' 'two' 'eight']
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    int8
#  3   fuel-type          205 non-null    int8
#  4   aspiration         205 non-null    int8
#  5   no-of-doors        205 non-null    int8
#  6   body-style         205 non-null    int8
#  7   drive-wheels       205 non-null    int8
#  8   engine-location    205 non-null    int8
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    int8
# ...

# %%
print("fuel-system",data['fuel-system'].unique())
print(data['bore'].unique())
print(data['stroke'].unique())

data[['fuel-system','bore','stroke']]=data[['fuel-system','bore','stroke']].astype('category')
data['fuel-system']=data['fuel-system'].cat.codes
data['bore']=data['bore'].cat.codes
data['stroke']=data['stroke'].cat.codes
data.info()
data.head()
# Out:
# fuel-system ['mpfi' '2bbl' 'mfi' '1bbl' 'spfi' '4bbl' 'idi' 'spdi']
# ['3.47' '2.68' '3.19' '3.13' '3.50' '3.31' '3.62' '2.91' '3.03' '2.97'
#  '3.34' '3.60' '2.92' '3.15' '3.43' '3.63' '3.54' '3.08' nan '3.39' '3.76'
#  '3.58' '3.46' '3.80' '3.78' '3.17' '3.35' '3.59' '2.99' '3.33' '3.70'
#  '3.61' '3.94' '3.74' '2.54' '3.05' '3.27' '3.24' '3.01']
# ['2.68' '3.47' '3.40' '2.80' '3.19' '3.39' '3.03' '3.11' '3.23' '3.46'
#  '3.90' '3.41' '3.07' '3.58' '4.17' '2.76' '3.15' nan '3.16' '3.64' '3.10'
#  '3.35' '3.12' '3.86' '3.29' '3.27' '3.52' '2.19' '3.21' '2.90' '2.07'
#  '2.36' '2.64' '3.08' '3.50' '3.54' '2.87']
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    int8
# ...

# %%
print("fuel-system",data['horse_power'].unique())
print(data['peak-rpm'].unique())
print(data['price'].unique())

data[['horse_power','peak-rpm','price']]=data[['horse_power','peak-rpm','price']].astype('category')
data['horse_power']=data['horse_power'].cat.codes
data['peak-rpm']=data['peak-rpm'].cat.codes
data['price']=data['price'].cat.codes
data.info()
data.head()
# Out:
# fuel-system ['111' '154' '102' '115' '110' '140' '160' '101' '121' '182' '48' '70'
#  '68' '88' '145' '58' '76' '60' '86' '100' '78' '90' '176' '262' '135'
#  '84' '64' '120' '72' '123' '155' '184' '175' '116' '69' '55' '97' '152'
#  '200' '95' '142' '143' '207' '288' nan '73' '82' '94' '62' '56' '112'
#  '92' '161' '156' '52' '85' '114' '162' '134' '106']
# ['5000' '5500' '5800' '4250' '5400' '5100' '4800' '6000' '4750' '4650'
#  '4200' '4350' '4500' '5200' '4150' '5600' '5900' '5750' nan '5250' '4900'
#  '4400' '6600' '5300']
# ['13495' '16500' '13950' '17450' '15250' '17710' '18920' '23875' nan
#  '16430' '16925' '20970' '21105' '24565' '30760' '41315' '36880' '5151'
#  '6295' '6575' '5572' '6377' '7957' '6229' '6692' '7609' '8558' '8921'
#  '12964' '6479' '6855' '5399' '6529' '7129' '7295' '7895' '9095' '8845'
#  '10295' '12945' '10345' '6785' '11048' '32250' '35550' '36000' '5195'
#  '6095' '6795' '6695' '7395' '10945' '11845' '13645' '15645' '8495'
# ...

# %%
X=data.iloc[:,0:25]
X
# Out:
#      symboling normalized-losses  make  fuel-type  aspiration  no-of-doors  \
# 0            3             122.0     0          1           0            1
# 1            3             122.0     0          1           0            1
# 2            1             122.0     0          1           0            1
# 3            2               164     1          1           0            0
# 4            2               164     1          1           0            0
# ..         ...               ...   ...        ...         ...          ...
# 200         -1                95    21          1           0            0
# 201         -1                95    21          1           1            0
# 202         -1                95    21          1           0            0
# 203         -1                95    21          0           1            0
# 204         -1                95    21          1           1            0
#
#      body-style  drive-wheels  engine-location  wheel-base  ...  \
# ...

# %%
y=data.iloc[:,25]
y
# Out:
# 0      31
# 1      50
# 2      50
# 3      36
# 4      61
#        ..
# 200    56
# 201    73
# 202    77
# 203    79
# 204    80
# Name: price, Length: 205, dtype: int16

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train, y_test = train_test_split(X,y ,test_size=0.2)

# %%
from sklearn.model_selection import LinearRegression
lr= LinearRegression()
lr.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 from sklearn.model_selection import LinearRegression
#       2 lr= LinearRegression()
#       3 lr.fit(x_train,y_train)
#
# ImportError: cannot import name 'LinearRegression' from 'sklearn.model_selection' (C:\Users\sharvani dhulipala\anaconda3\Lib\site-packages\sklearn\model_selection\__init__.py)

# %%
pred=lr.predict(X_train)
